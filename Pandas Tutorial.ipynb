# %% [markdown]
# # PANDAS

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":['harry','rohan','skillf','shubh'],
    "marks":[92,34,24,17],
    "city":['rampur','kolkata','bareilly','antarctica']
}

# %%
df = pd.DataFrame(dict1) # CREATING DATAFRAME

# %%
df # DISPLAYING THE DATAFRAME
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
df.to_csv('friends.csv') # CONVERTING TO CSV FILE

# %%
df.to_csv('friends_index_false.csv',index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
df.tail(2)
# Out:
#      name  marks        city
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#    TRAIN NO  SPEED        CITY
# 0     21356     34      rampur
# 1     98501    123     kolkata
# 2     56903     67    bareilly
# 3     56931     87  antarctica

# %%
train['SPEED'][0] = 50
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19280\409529588.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['SPEED'][0] = 50

# %%
train
# Out:
#    TRAIN NO  SPEED        CITY
# 0     21356     50      rampur
# 1     98501    123     kolkata
# 2     56903     67    bareilly
# 3     56931     87  antarctica

# %%
train.to_csv('train.csv')

# %%
train.index = ['first','second','third','fourth']

# %%
train
# Out:
#         TRAIN NO  SPEED        CITY
# first      21356     50      rampur
# second     98501    123     kolkata
# third      56903     67    bareilly
# fourth     56931     87  antarctica

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.327039
# 1     0.220701
# 2     0.541610
# 3     0.301131
# 4     0.347603
# 5     0.051405
# 6     0.417010
# 7     0.722650
# 8     0.335347
# 9     0.676497
# 10    0.527698
# 11    0.730288
# 12    0.055171
# 13    0.430665
# 14    0.487696
# 15    0.711824
# 16    0.465011
# 17    0.453585
# 18    0.495255
# 19    0.155612
# 20    0.426601
# 21    0.606046
# 22    0.692777
# 23    0.146776
# 24    0.138385
# 25    0.139916
# 26    0.660575
# 27    0.694841
# 28    0.512832
# 29    0.843620
# 30    0.297196
# 31    0.022615
# 32    0.388033
# 33    0.351397
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.735051  0.833961  0.819105  0.109505  0.758193
# 1    0.663561  0.249016  0.838789  0.243978  0.521875
# 2    0.122098  0.493968  0.343163  0.728223  0.985278
# 3    0.268365  0.746257  0.932725  0.771868  0.387509
# 4    0.284250  0.305284  0.397643  0.085387  0.363490
# ..        ...       ...       ...       ...       ...
# 329  0.857601  0.442695  0.756963  0.616040  0.877084
# 330  0.436915  0.500348  0.177743  0.602308  0.001643
# 331  0.116031  0.759986  0.539789  0.755125  0.886205
# 332  0.023997  0.431310  0.690952  0.493907  0.315291
# 333  0.100702  0.896599  0.379252  0.820768  0.992993
#
# [334 rows x 5 columns]

# %%
type(newdf)
newdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(newdf)
#       2 newdf.head()
#
# NameError: name 'newdf' is not defined

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.486671    0.476205    0.506496    0.500528    0.499606
# std      0.290525    0.306859    0.285853    0.290276    0.290007
# min      0.001006    0.002901    0.000714    0.002807    0.000530
# 25%      0.209279    0.180776    0.264983    0.244440    0.223128
# 50%      0.494405    0.469002    0.523051    0.478744    0.529118
# 75%      0.725638    0.728343    0.754670    0.749237    0.750809
# max      0.999375    0.996730    0.988156    0.999455    0.998675

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0] = "abc"

# %%
newdf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0
# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0       654  0.223500  0.822610  0.568588  0.589242
# 1  0.886026  0.754362  0.670397  0.663531  0.383504
# 2   0.34852  0.414078  0.745750  0.715781  0.708124
# 3  0.327451  0.670693  0.379806  0.476724  0.148886
# 4  0.735154  0.152911  0.507622  0.093561  0.077613

# %%
newdf.columns = list("ABCDE")

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0       654  0.223500  0.822610  0.568588  0.589242
# 1  0.886026  0.754362  0.670397  0.663531  0.383504
# 2   0.34852  0.414078  0.745750  0.715781  0.708124
# 3  0.327451  0.670693  0.379806  0.476724  0.148886
# 4  0.735154  0.152911  0.507622  0.093561  0.077613

# %%
newdf.loc[0,0] = 654

# %%
newdf.head()
# Out:
#           A         B         C         D         E      0
# 0       654  0.223500  0.822610  0.568588  0.589242  654.0
# 1  0.886026  0.754362  0.670397  0.663531  0.383504    NaN
# 2   0.34852  0.414078  0.745750  0.715781  0.708124    NaN
# 3  0.327451  0.670693  0.379806  0.476724  0.148886    NaN
# 4  0.735154  0.152911  0.507622  0.093561  0.077613    NaN

# %%
newdf.loc[0,'A'] = 657

# %%
newdf.head()
# Out:
#           A         B         C         D         E      0
# 0       657  0.223500  0.822610  0.568588  0.589242  654.0
# 1  0.886026  0.754362  0.670397  0.663531  0.383504    NaN
# 2   0.34852  0.414078  0.745750  0.715781  0.708124    NaN
# 3  0.327451  0.670693  0.379806  0.476724  0.148886    NaN
# 4  0.735154  0.152911  0.507622  0.093561  0.077613    NaN

# %%
newdf = newdf.drop(0,axis = 1)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0       657  0.223500  0.822610  0.568588  0.589242
# 1  0.886026  0.754362  0.670397  0.663531  0.383504
# 2   0.34852  0.414078  0.745750  0.715781  0.708124
# 3  0.327451  0.670693  0.379806  0.476724  0.148886
# 4  0.735154  0.152911  0.507622  0.093561  0.077613

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.670397  0.663531
# 2  0.745750  0.715781

# %%
newdf.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.822610  0.568588
# 1    0.670397  0.663531
# 2    0.745750  0.715781
# 3    0.379806  0.476724
# 4    0.507622  0.093561
# ..        ...       ...
# 329  0.871461  0.222201
# 330  0.506443  0.616973
# 331  0.051661  0.902563
# 332  0.931394  0.901884
# 333  0.881204  0.016872
#
# [334 rows x 2 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.886026  0.754362  0.670397  0.663531  0.383504
# 2   0.34852  0.414078  0.745750  0.715781  0.708124

# %%
newdf.loc[(newdf['A']<0.3)]
# Out:
#             A         B         C         D         E
# 7    0.169489  0.793266  0.831851  0.477880  0.566971
# 16   0.104204  0.120275  0.631214  0.377228  0.866415
# 18   0.111526  0.006342  0.707790  0.970411  0.812418
# 19   0.115293  0.363937  0.492567  0.379002  0.839642
# 23   0.144454  0.145184  0.080494  0.836510  0.329831
# ..        ...       ...       ...       ...       ...
# 319  0.032027  0.780402  0.645327  0.636148  0.762185
# 322  0.154124  0.885575  0.297170  0.449342  0.196510
# 328  0.022067  0.512252  0.596059  0.470812  0.490126
# 330  0.166871  0.052845  0.506443  0.616973  0.696963
# 332  0.140546  0.241383  0.931394  0.901884  0.644937
#
# [104 rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E
# 7    0.169489  0.793266  0.831851  0.477880  0.566971
# 16   0.104204  0.120275  0.631214  0.377228  0.866415
# 18   0.111526  0.006342  0.707790  0.970411  0.812418
# 19   0.115293  0.363937  0.492567  0.379002  0.839642
# 30   0.046721  0.013225  0.685049  0.425411  0.698928
# ..        ...       ...       ...       ...       ...
# 319  0.032027  0.780402  0.645327  0.636148  0.762185
# 322  0.154124  0.885575  0.297170  0.449342  0.196510
# 328  0.022067  0.512252  0.596059  0.470812  0.490126
# 330  0.166871  0.052845  0.506443  0.616973  0.696963
# 332  0.140546  0.241383  0.931394  0.901884  0.644937
#
# [92 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0       657  0.223500  0.822610  0.568588  0.589242
# 1  0.886026  0.754362  0.670397  0.663531  0.383504
# 2   0.34852  0.414078  0.745750  0.715781  0.708124
# 3  0.327451  0.670693  0.379806  0.476724  0.148886
# 4  0.735154  0.152911  0.507622  0.093561  0.077613

# %%
newdf.iloc[0][4]
# Out:
# 0.5892415124904918

# %%
newdf.iloc[[0,1],[1,2]]
# Out:
#           B         C
# 0  0.223500  0.822610
# 1  0.754362  0.670397

# %%
newdf.iloc[[0,1],:]
# Out:
#           A         B         C         D         E
# 0       657  0.223500  0.822610  0.568588  0.589242
# 1  0.886026  0.754362  0.670397  0.663531  0.383504

# %%
newdf.drop(['A','C'],axis=1,inplace = True)

# %%
newdf
# Out:
#             B         D         E
# 0    0.223500  0.568588  0.589242
# 1    0.754362  0.663531  0.383504
# 2    0.414078  0.715781  0.708124
# 3    0.670693  0.476724  0.148886
# 4    0.152911  0.093561  0.077613
# ..        ...       ...       ...
# 329  0.744895  0.222201  0.997990
# 330  0.052845  0.616973  0.696963
# 331  0.434780  0.902563  0.588182
# 332  0.241383  0.901884  0.644937
# 333  0.604204  0.016872  0.430047
#
# [334 rows x 3 columns]

# %%
newdf.drop([1,3,5],inplace = True)

# %%
newdf.head(3)
# Out:
#           B         D         E
# 0  0.223500  0.568588  0.589242
# 2  0.414078  0.715781  0.708124
# 4  0.152911  0.093561  0.077613

# %%
newdf.reset_index()
# Out:
#      index         B         D         E
# 0        0  0.223500  0.568588  0.589242
# 1        2  0.414078  0.715781  0.708124
# 2        4  0.152911  0.093561  0.077613
# 3        6  0.627815  0.990792  0.796645
# 4        7  0.793266  0.477880  0.566971
# ..     ...       ...       ...       ...
# 326    329  0.744895  0.222201  0.997990
# 327    330  0.052845  0.616973  0.696963
# 328    331  0.434780  0.902563  0.588182
# 329    332  0.241383  0.901884  0.644937
# 330    333  0.604204  0.016872  0.430047
#
# [331 rows x 4 columns]

# %%
newdf.reset_index(drop = True,inplace = True)

# %%
newdf.head()
# Out:
#           B         D         E
# 0  0.223500  0.568588  0.589242
# 1  0.414078  0.715781  0.708124
# 2  0.152911  0.093561  0.077613
# 3  0.627815  0.990792  0.796645
# 4  0.793266  0.477880  0.566971

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 326    False
# 327    False
# 328    False
# 329    False
# 330    False
# Name: B, Length: 331, dtype: bool

# %%
newdf.loc[:,['B']] = None

# %%
newdf.head()
# Out:
#       B         D         E
# 0  None  0.568588  0.589242
# 1  None  0.715781  0.708124
# 2  None  0.093561  0.077613
# 3  None  0.990792  0.796645
# 4  None  0.477880  0.566971

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 326    True
# 327    True
# 328    True
# 329    True
# 330    True
# Name: B, Length: 331, dtype: bool
